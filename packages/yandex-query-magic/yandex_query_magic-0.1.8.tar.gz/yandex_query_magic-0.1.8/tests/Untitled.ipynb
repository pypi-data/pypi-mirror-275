# %%
# %reload_ext yandex_query_magic

# %%
# %load_ext yandex_query_magic

# %%
# %yq_settings --folder-id b1ggt6geu4aa38p61kst --sa-file-auth /home/slonn/sa_key.json

# %%
# %yq select * from `tutorial-analytics` limit 10
# Out:
# ...
#   DOLocationID PULocationID  RatecodeID VendorID  airport_fee  \
# 0          141          138         1.0        1         1.25
# 1           42          238         1.0        2         0.00
# 2           74          239         1.0        1         0.00
# 3           87          148         1.0        1         0.00
# 4          246          231         1.0        1         0.00
# 5           75          132         2.0        2         1.25
# 6          239          114         1.0        2         0.00
# 7           90          143         1.0        2         0.00
# 8          236          138         1.0        1         1.25
# 9           43          141         1.0        1         0.00
#
#    congestion_surcharge  extra  fare_amount  improvement_surcharge  month  \
# 0                   2.5   4.25         26.5                    0.3     12
# 1                   2.5   0.50         13.0                    0.3     12
# ...

# %%
# %%yq
# select 1;
# select 2;
# Out:
# ...
#    column0
# 0        1

# %%
# %%yq --all-results
# select 1;
# select 2;
# Out:
# ...
# [   column0
#  0        1,
#     column0
#  0        2]

# %%
# %%yq --all-results
# output << select 1;
# select 2;
# Out:
# ...
# [   column0
#  0        1,
#     column0
#  0        2]

# %%
output[0]
# Out:
#    column0
# 0        1

# %%
output[1]
# Out:
#    column0
# 0        2
